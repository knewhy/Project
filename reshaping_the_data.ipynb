# %% [markdown]
# This project that I'm gonna do is "Seven Clean Steps To Reshape Your Data With Pandas Or How I Use Python Where Excel Fails" by Tich Mangono (https://towardsdatascience.com/seven-clean-steps-to-reshape-your-data-with-pandas-or-how-i-use-python-where-excel-fails-62061f86ef9c).
# Let's say that I'm gonna follow his concepts + steps then learn from it and try to explain with my language and knowledge. His article contains these concepts :
# #### • multi-level indexing • pivoting • stacking • apply • lambda and list-comprehension
# The dataset that used in this project is a spreadsheet with data on a public health intervention, consisting of many tabs, one tab per organization.
# The problem was that the data was in wide format, but we needed a long format. So instead of copy-and-paste over and over, we can use Python’s Pandas library to automate this task !

# %% [markdown]
# #### Here’s a road map of what we will do with Pandas:
# 1. Set up the environment and load the data
# 2. Investigate the data
# 3. Parse the different data tabs
# 4. Standardize existing columns and create new ones
# 5. Clean up the data using “apply” and “lambda” functions
# 6. Reshape the data from wide to long by pivoting on multi-level indices and stacking
# 7. Concatenate and save the final results back to Excel

# %% [markdown]
# ### So let's BEGIN !

# %% [markdown]
# # 1. Set up the environment and load the data

# %%
# just Lin-Bing and our data !
import pandas as pd
data = pd.ExcelFile('reshaping_data.xlsx')

# %% [markdown]
# # 2. Investigate the data

# %%
# let see all of its sheetname
data.sheet_names
# Out:
# ['ABC_inc', 'HIJ_inc', 'OPQ_inc', 'XYZ_inc']

# %%
# and then its first 10 rows of first tab(if you use .head() it'll be 5 rows and you won't understand the sheet)
data.parse(sheet_name='ABC_inc', skiprows=0).head(10)
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN        NaN        NaN             NaN         NaN
# 1         NaN         NaN        NaN        NaN             NaN         NaN
# 2         NaN         NaN        NaN        NaN             NaN         NaN
# 3         NaN         NaN        NaN        NaN             NaN         NaN
# 4         NaN         NaN        NaN        NaN             NaN         NaN
# 5         NaN         NaN        NaN        NaN             NaN         NaN
# 6         NaN    district   province    partner  funding_source         NaN
# 7         NaN         NaN        NaN        NaN             NaN         NaN
# 8         NaN  District 1   Region 1  partner 1         Souce 2         NaN
# 9         NaN  District 2   Region 3  partner 6         Souce 5         NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 21  Unnamed: 22  \
# 0         NaN        NaN        NaN        NaN  ...         NaN          NaN
# 1         NaN        NaN        NaN        NaN  ...         NaN          NaN
# 2         NaN        NaN        NaN        NaN  ...         NaN          NaN
# 3         NaN        NaN        NaN        NaN  ...         NaN          NaN
# 4         NaN        NaN        NaN        NaN  ...         NaN          NaN
# 5         NaN        NaN        NaN      Year1  ...         NaN          NaN
# 6         NaN       2017       2017       2017  ...         NaN         2020
# 7         NaN   10-14yrs   15-29yrs     30+yrs  ...         NaN     10-14yrs
# 8         NaN       1296        383       1571  ...         NaN         1906
# 9         NaN        722        232       1848  ...         NaN          810
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN          NaN         NaN
# 1         NaN         NaN         NaN         NaN          NaN         NaN
# 2         NaN         NaN         NaN         NaN          NaN         NaN
# 3         NaN         NaN         NaN         NaN          NaN         NaN
# 4         NaN         NaN         NaN         NaN          NaN         NaN
# 5       Year4         NaN         NaN         NaN          NaN       Year5
# 6        2020        2020        2020         NaN         2021        2021
# 7    15-29yrs      30+yrs       Total         NaN     10-14yrs    15-29yrs
# 8        1925         931        5465         NaN           61         353
# 9         664         452        3665         NaN          989         374
#
#   Unnamed: 29 Unnamed: 30
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# 5         NaN         NaN
# 6        2021        2021
# 7      30+yrs       Total
# 8        1091        2409
# 9        1790        4320
#
# [10 rows x 31 columns]

# %% [markdown]
# Now you'll see that the header is start at row 6 !

# %% [markdown]
# # 3. Parse the different data tabs

# %% [markdown]
# Make a list of your target tab names. In our case we want all of them.
# You can just make your own like just a ['ABC_inc', 'HIJ_inc'] if you want.

# %%
tabnames = data.sheet_names
# let's see what it look like
tabnames
# Out:
# ['ABC_inc', 'HIJ_inc', 'OPQ_inc', 'XYZ_inc']

# %% [markdown]
# because the tabs have a same format so we will use only one them for this demonstration and we'll combine it at the end. Let parse the tab into a data frame, skipping the first 6 rows that we don't want. Don't forget to use “data.head()” to check result !

# %%
print(tabnames[0])

i = 0
df = data.parse(sheet_name=tabnames[i], skiprows=7)
df.head()
# Out:
# ABC_inc
#    Unnamed: 0    district  province    partner funding_source  Unnamed: 5  \
# 0         NaN         NaN       NaN        NaN            NaN         NaN
# 1         NaN  District 1  Region 1  partner 1        Souce 2         NaN
# 2         NaN  District 2  Region 3  partner 6        Souce 5         NaN
# 3         NaN  District 3  Region 1  partner 1        Souce 2         NaN
# 4         NaN  District 4  Region 3  partner 6        Souce 5         NaN
#
#    Unnamed: 6      2017    2017.1  2017.2  ... Unnamed: 21      2020  \
# 0         NaN  10-14yrs  15-29yrs  30+yrs  ...         NaN  10-14yrs
# 1         NaN      1296       383    1571  ...         NaN      1906
# 2         NaN       722       232    1848  ...         NaN       810
# 3         NaN       545       585    1736  ...         NaN      1890
# 4         NaN       631      1413      31  ...         NaN      1646
#
#      2020.1  2020.2 2020.3 Unnamed: 26      2021    2021.1  2021.2 2021.3
# 0  15-29yrs  30+yrs  Total         NaN  10-14yrs  15-29yrs  30+yrs  Total
# 1      1925     931   5465         NaN        61       353    1091   2409
# 2       664     452   3665         NaN       989       374    1790   4320
# 3       736    1414   5311         NaN      1215       112    1475   2824
# 4       960     209   2956         NaN      1392       936     701   4903
#
# [5 rows x 31 columns]

# %% [markdown]
# # 4. Standardize existing columns and create new ones

# %% [markdown]
# make a list of the header row and strip up to the 4th letter. This is the location and year information

# %%
cols1 = list(df.columns)
cols1_year = [str(x)[:4] for x in cols1]
cols1_year
# Out:
# ['Unna',
#  'dist',
#  'prov',
#  'part',
#  'fund',
#  'Unna',
#  'Unna',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  'Unna',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  'Unna',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  'Unna',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  'Unna',
#  '2021',
#  '2021',
#  '2021',
#  '2021']

# %% [markdown]
# Now we got location and year information ! Now make another list of the first row, this is the age group information we need to preserve this information in the column name when we reshape the data .

# %%
cols2 = list(df.iloc[0,:])
cols2_age = [str(x) for x in cols2]
cols2_age
# Out:
# ['nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  '10-14yrs',
#  '15-29yrs',
#  '30+yrs',
#  'Total',
#  'nan',
#  '10-14yrs',
#  '15-29yrs',
#  '30+yrs',
#  'Total',
#  'nan',
#  '10-14yrs',
#  '15-29yrs',
#  '30+yrs',
#  'Total',
#  'nan',
#  '10-14yrs',
#  '15-29yrs',
#  '30+yrs',
#  'Total',
#  'nan',
#  '10-14yrs',
#  '15-29yrs',
#  '30+yrs',
#  'Total']

# %% [markdown]
# And that's a age-group information ! Then join the two lists to make a combined column name which preserves our location, year and age-group information.

# %%
cols = [x+"_"+y for x,y in zip(cols1_year,cols2_age)]
cols
# Out:
# ['Unna_nan',
#  'dist_nan',
#  'prov_nan',
#  'part_nan',
#  'fund_nan',
#  'Unna_nan',
#  'Unna_nan',
#  '2017_10-14yrs',
#  '2017_15-29yrs',
#  '2017_30+yrs',
#  '2017_Total',
#  'Unna_nan',
#  '2018_10-14yrs',
#  '2018_15-29yrs',
#  '2018_30+yrs',
#  '2018_Total',
#  'Unna_nan',
#  '2019_10-14yrs',
#  '2019_15-29yrs',
#  '2019_30+yrs',
#  '2019_Total',
#  'Unna_nan',
#  '2020_10-14yrs',
#  '2020_15-29yrs',
#  '2020_30+yrs',
#  '2020_Total',
#  'Unna_nan',
#  '2021_10-14yrs',
#  '2021_15-29yrs',
#  '2021_30+yrs',
#  '2021_Total']

# %% [markdown]
# Nice ! Next Let's assign new column names to the dataframe

# %%
df.columns = cols
df.head(2)
# Out:
#   Unna_nan    dist_nan  prov_nan   part_nan fund_nan Unna_nan Unna_nan  \
# 0      NaN         NaN       NaN        NaN      NaN      NaN      NaN
# 1      NaN  District 1  Region 1  partner 1  Souce 2      NaN      NaN
#
#   2017_10-14yrs 2017_15-29yrs 2017_30+yrs  ... Unna_nan  2020_10-14yrs  \
# 0      10-14yrs      15-29yrs      30+yrs  ...      NaN       10-14yrs
# 1          1296           383        1571  ...      NaN           1906
#
#   2020_15-29yrs 2020_30+yrs 2020_Total Unna_nan  2021_10-14yrs 2021_15-29yrs  \
# 0      15-29yrs      30+yrs      Total      NaN       10-14yrs      15-29yrs
# 1          1925         931       5465      NaN             61           353
#
#   2021_30+yrs 2021_Total
# 0      30+yrs      Total
# 1        1091       2409
#
# [2 rows x 31 columns]

# %% [markdown]
# Then drop empty columns, Rename the useful columns.

# %%
df = df.drop(["Unna_nan"], axis=1).iloc[1:,:].rename(columns=    {'dist_nan':'district','prov_nan': 'province','part_nan':'partner','fund_nan':'financing_source'})
df.head(2)
# Out:
#      district  province    partner financing_source 2017_10-14yrs  \
# 1  District 1  Region 1  partner 1          Souce 2          1296
# 2  District 2  Region 3  partner 6          Souce 5           722
#
#   2017_15-29yrs 2017_30+yrs 2017_Total 2018_10-14yrs 2018_15-29yrs  ...  \
# 1           383        1571       3250           189           854  ...
# 2           232        1848       2802           972            69  ...
#
#   2019_30+yrs 2019_Total 2020_10-14yrs 2020_15-29yrs 2020_30+yrs 2020_Total  \
# 1         491       2256          1906          1925         931       5465
# 2         245       2957           810           664         452       3665
#
#   2021_10-14yrs 2021_15-29yrs 2021_30+yrs 2021_Total
# 1            61           353        1091       2409
# 2           989           374        1790       4320
#
# [2 rows x 24 columns]

# %%
# Engineer a new column for the organization, grab this name from the excel tab name
# This should read 'ABC inc' if executed correctly
df['main_organization'] = tabnames[i].split("_")[0] + " "+ tabnames[i].split("_")[1]
df.main_organization.head()
# Out:
# 1    ABC inc
# 2    ABC inc
# 3    ABC inc
# 4    ABC inc
# 5    ABC inc
# Name: main_organization, dtype: object

# %% [markdown]
# Let's take a break and look at our data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 25 columns):
# district             10 non-null object
# province             10 non-null object
# partner              10 non-null object
# financing_source     10 non-null object
# 2017_10-14yrs        10 non-null object
# 2017_15-29yrs        10 non-null object
# 2017_30+yrs          10 non-null object
# 2017_Total           10 non-null object
# 2018_10-14yrs        10 non-null object
# 2018_15-29yrs        10 non-null object
# 2018_30+yrs          10 non-null object
# 2018_Total           10 non-null object
# 2019_10-14yrs        10 non-null object
# 2019_15-29yrs        10 non-null object
# 2019_30+yrs          10 non-null object
# 2019_Total           10 non-null object
# 2020_10-14yrs        10 non-null object
# 2020_15-29yrs        10 non-null object
# 2020_30+yrs          10 non-null object
# 2020_Total           10 non-null object
# 2021_10-14yrs        10 non-null object
# 2021_15-29yrs        10 non-null object
# 2021_30+yrs          10 non-null object
# 2021_Total           10 non-null object
# main_organization    10 non-null object
# dtypes: object(25)
# memory usage: 2.0+ KB

# %% [markdown]
# Now we have 29 columns but all they're “object” data type, there should be a lot of numeric type and the column names still retain multiple levels of information, i.e. the year and the age-group !

# %% [markdown]
# # 5. Clean up the data using “apply” and “lambda” functions

# %% [markdown]
# Let’s remove more redundant columns and change the data types.

# %%
# Make lists of the columns which need attention and use this as reference to execute
to_remove = [c for c in df.columns if "Total" in c] # redundant
to_change = [c for c in df.columns if "yrs" in c] # numeric
# drop unwanted columns
# Notice that you need to specify inplace, otherwise pandas will return the data frame instead of changing it in place
df.drop(to_remove, axis=1, inplace= True) 
# Change the target column data types
for c in to_change:
    df[c] = df[c].apply(lambda x: pd.to_numeric(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 20 columns):
# district             10 non-null object
# province             10 non-null object
# partner              10 non-null object
# financing_source     10 non-null object
# 2017_10-14yrs        10 non-null int64
# 2017_15-29yrs        10 non-null int64
# 2017_30+yrs          10 non-null int64
# 2018_10-14yrs        10 non-null int64
# 2018_15-29yrs        10 non-null int64
# 2018_30+yrs          10 non-null int64
# 2019_10-14yrs        10 non-null int64
# 2019_15-29yrs        10 non-null int64
# 2019_30+yrs          10 non-null int64
# 2020_10-14yrs        10 non-null int64
# 2020_15-29yrs        10 non-null int64
# 2020_30+yrs          10 non-null int64
# 2021_10-14yrs        10 non-null int64
# 2021_15-29yrs        10 non-null int64
# 2021_30+yrs          10 non-null int64
# main_organization    10 non-null object
# dtypes: int64(15), object(5)
# memory usage: 1.6+ KB

# %% [markdown]
# Now the Total column is gone and we got year column in numeric data type !

# %% [markdown]
# # 6. Reshape the data from wide to long by pivoting on multi-level indices and stacking

# %% [markdown]
# Right now the data is in a wide format, but we need to change it to long format so that we can easily transfer it to Excel where long formats lend themselves to quick pivot tables and dashboard creation very easily.

# %%
# First, select the columns to use for a multi-level index. This depends on your data
# Generally, you want all the identifier columns to be included in the multi-index 
# For this dataset, this is every non-numeric column
idx =['district','province','partner','financing_source','main_organization']
# Then pivot the dataset based on this multi-level index 
multi_indexed_df = df.set_index(idx)
multi_indexed_df.head(2)
# Out:
#                                                                   2017_10-14yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                     1296
# District 2 Region 3 partner 6 Souce 5          ABC inc                      722
#
#                                                                   2017_15-29yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                      383
# District 2 Region 3 partner 6 Souce 5          ABC inc                      232
#
#                                                                   2017_30+yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                   1571
# District 2 Region 3 partner 6 Souce 5          ABC inc                   1848
#
#                                                                   2018_10-14yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                      189
# District 2 Region 3 partner 6 Souce 5          ABC inc                      972
#
#                                                                   2018_15-29yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                      854
# District 2 Region 3 partner 6 Souce 5          ABC inc                       69
#
#                                                                   2018_30+yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                    339
# District 2 Region 3 partner 6 Souce 5          ABC inc                   1205
#
#                                                                   2019_10-14yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                      840
# District 2 Region 3 partner 6 Souce 5          ABC inc                      422
#
#                                                                   2019_15-29yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                      773
# District 2 Region 3 partner 6 Souce 5          ABC inc                      676
#
#                                                                   2019_30+yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                    491
# District 2 Region 3 partner 6 Souce 5          ABC inc                    245
#
#                                                                   2020_10-14yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                     1906
# District 2 Region 3 partner 6 Souce 5          ABC inc                      810
#
#                                                                   2020_15-29yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                     1925
# District 2 Region 3 partner 6 Souce 5          ABC inc                      664
#
#                                                                   2020_30+yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                    931
# District 2 Region 3 partner 6 Souce 5          ABC inc                    452
#
#                                                                   2021_10-14yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                       61
# District 2 Region 3 partner 6 Souce 5          ABC inc                      989
#
#                                                                   2021_15-29yrs  \
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                      353
# District 2 Region 3 partner 6 Souce 5          ABC inc                      374
#
#                                                                   2021_30+yrs
# district   province partner   financing_source main_organization
# District 1 Region 1 partner 1 Souce 2          ABC inc                   1091
# District 2 Region 3 partner 6 Souce 5          ABC inc                   1790

# %% [markdown]
# After pivoting the data frame on our strategically engineered multi-level index, we will now stack all the numerical columns. This will give us the flexibility to reshape the data back to whatever level we want afterwards.

# %%
# Stack the columns to achieve the baseline long format for the data
stacked_df = multi_indexed_df.stack(dropna=False)
stacked_df.head(25) # check out the results!
# Out:
# district    province  partner    financing_source  main_organization
# District 1  Region 1  partner 1  Souce 2           ABC inc            2017_10-14yrs    1296
#                                                                       2017_15-29yrs     383
#                                                                       2017_30+yrs      1571
#                                                                       2018_10-14yrs     189
#                                                                       2018_15-29yrs     854
#                                                                       2018_30+yrs       339
#                                                                       2019_10-14yrs     840
#                                                                       2019_15-29yrs     773
#                                                                       2019_30+yrs       491
#                                                                       2020_10-14yrs    1906
#                                                                       2020_15-29yrs    1925
#                                                                       2020_30+yrs       931
#                                                                       2021_10-14yrs      61
#                                                                       2021_15-29yrs     353
#                                                                       2021_30+yrs      1091
# District 2  Region 3  partner 6  Souce 5           ABC inc            2017_10-14yrs     722
#                                                                       2017_15-29yrs     232
#                                                                       2017_30+yrs      1848
#                                                                       2018_10-14yrs     972
#                                                                       2018_15-29yrs      69
#                                                                       2018_30+yrs      1205
#                                                                       2019_10-14yrs     422
#                                                                       2019_15-29yrs     676
#                                                                       2019_30+yrs       245
#                                                                       2020_10-14yrs     810
# dtype: int64

# %% [markdown]
# It's gettin in shape !

# %%
# Now do a reset to disband the multi-level index, we only needed it to pivot our data during the reshape
long_df = stacked_df.reset_index()
long_df.head(3)
# Out:
#      district  province    partner financing_source main_organization  \
# 0  District 1  Region 1  partner 1          Souce 2           ABC inc
# 1  District 1  Region 1  partner 1          Souce 2           ABC inc
# 2  District 1  Region 1  partner 1          Souce 2           ABC inc
#
#          level_5     0
# 0  2017_10-14yrs  1296
# 1  2017_15-29yrs   383
# 2    2017_30+yrs  1571

# %% [markdown]
# Notice that the “level_5” column contains two pieces of information. This was deliberately done from the beginning so as not to lose any information along the way as we drop some columns and rows. Now, lets use string manipulation to separate these and delete any redundancies after that.

# %%
# Make series of lists which split year from target age-group
# the .str attribute is how you manipulate the data frame objects and columns with strings in them
col_str = long_df.level_5.str.split("_") 
col_str.head(3)

# engineer the columns we want, one columns takes the first item in col_str and another columns takes the second 
long_df['target_year'] = [x[0] for x in col_str] 
long_df['target_age'] = [x[1] for x in col_str]
long_df['target_quantity'] = long_df[0] # rename this column
long_df.head(2)
# Out:
#      district  province    partner financing_source main_organization  \
# 0  District 1  Region 1  partner 1          Souce 2           ABC inc
# 1  District 1  Region 1  partner 1          Souce 2           ABC inc
#
#          level_5     0 target_year target_age  target_quantity
# 0  2017_10-14yrs  1296        2017   10-14yrs             1296
# 1  2017_15-29yrs   383        2017   15-29yrs              383

# %%
# drop the now redundant columns
df_final = long_df.drop(['level_5', 0], axis=1)
df_final.head(2)
# Out:
#      district  province    partner financing_source main_organization
# 0  District 1  Region 1  partner 1          Souce 2           ABC inc
# 1  District 1  Region 1  partner 1          Souce 2           ABC inc

# %% [markdown]
# # 7. Concatenate and save the final results back to Excel

# %% [markdown]
# Now we have all the ingredients we need, we can define a function to automate the reshape, use iteration to apply this function to any number of tabs we want and then finally save this to our spreadsheet of choice! Notice that in the function I combine the shapes and add an assertion to check that the inputs are correct, but it mostly the same code.

# %%
# Now define a function for doing the reshape
def ReshapeFunc(excel_obj, i):
    """ Takes in an excel file object with multiple tabs in a wide format, and a specified index of the tab to be parsed and reshaped. Returns a data frame of the specified tab reshaped to long format"""

    tabnames = data.sheet_names
    assert i < len(tabnames), "Your tab index exceeds the number of available tabs, try a lower number" 
    
    # parse and clean columns
    df = excel_obj.parse(sheet_name=tabnames[i], skiprows=7)
    cols1 = [str(x)[:4] for x in list(df.columns)]
    cols2 = [str(x) for x in list(df.iloc[0,:])]
    cols = [x+"_"+y for x,y in zip(cols1,cols2)]
    df.columns = cols
    df = df.drop(["Unna_nan"], axis=1).iloc[1:,:].rename(columns={'dist_nan':'district','prov_nan': 'province','part_nan':'partner','fund_nan':'financing_source'})
    # new columns, drop some and change data type
    df['main_organization'] = tabnames[i].split("_")[0] + " "+ tabnames[i].split("_")[1]
    df.drop([c for c in df.columns if "Total" in c], axis=1, inplace= True) 
    
    for c in [c for c in df.columns if "yrs" in c]:
        df[c] = df[c].apply(lambda x: pd.to_numeric(x))
    # reshape - indexing, pivoting and stacking
    idx = ['district','province', 'partner','financing_source','main_organization']
    multi_indexed_df = df.set_index(idx)
    stacked_df = multi_indexed_df.stack(dropna=False)
    long_df = stacked_df.reset_index()
    
    # clean up and finalize
    col_str = long_df.level_5.str.split("_") 
    long_df['target_year'] = [x[0] for x in col_str] 
    long_df['target_age'] = [x[1] for x in col_str]
    long_df['target_quantity'] = long_df[0] # rename this column
    df_final = long_df.drop(['level_5', 0], axis=1)
    return df_final

# %%
# Check that our function works:
check_df = ReshapeFunc(data, 2)
check_df.head(2)
# Out:
#       district  province    partner financing_source main_organization  \
# 0  District 19  Region 4  partner 3          Souce 4           OPQ inc
# 1  District 19  Region 4  partner 3          Souce 4           OPQ inc
#
#   target_year target_age  target_quantity
# 0        2017   10-14yrs                1
# 1        2017   15-29yrs              974

# %%
dfs_list = [ReshapeFunc(data, i) for i in range(4)]
concat_dfs  = pd.concat(dfs_list)
concat_dfs.to_excel("reshaping_result_long_format.xlsx")

# %%
concat_dfs
# Out:
#         district  province    partner financing_source main_organization  \
# 0     District 1  Region 1  partner 1          Souce 2           ABC inc
# 1     District 1  Region 1  partner 1          Souce 2           ABC inc
# 2     District 1  Region 1  partner 1          Souce 2           ABC inc
# 3     District 1  Region 1  partner 1          Souce 2           ABC inc
# 4     District 1  Region 1  partner 1          Souce 2           ABC inc
# 5     District 1  Region 1  partner 1          Souce 2           ABC inc
# 6     District 1  Region 1  partner 1          Souce 2           ABC inc
# 7     District 1  Region 1  partner 1          Souce 2           ABC inc
# 8     District 1  Region 1  partner 1          Souce 2           ABC inc
# 9     District 1  Region 1  partner 1          Souce 2           ABC inc
# 10    District 1  Region 1  partner 1          Souce 2           ABC inc
# 11    District 1  Region 1  partner 1          Souce 2           ABC inc
# 12    District 1  Region 1  partner 1          Souce 2           ABC inc
# 13    District 1  Region 1  partner 1          Souce 2           ABC inc
# 14    District 1  Region 1  partner 1          Souce 2           ABC inc
# 15    District 2  Region 3  partner 6          Souce 5           ABC inc
# 16    District 2  Region 3  partner 6          Souce 5           ABC inc
# 17    District 2  Region 3  partner 6          Souce 5           ABC inc
# 18    District 2  Region 3  partner 6          Souce 5           ABC inc
# 19    District 2  Region 3  partner 6          Souce 5           ABC inc
# 20    District 2  Region 3  partner 6          Souce 5           ABC inc
# 21    District 2  Region 3  partner 6          Souce 5           ABC inc
# 22    District 2  Region 3  partner 6          Souce 5           ABC inc
# 23    District 2  Region 3  partner 6          Souce 5           ABC inc
# 24    District 2  Region 3  partner 6          Souce 5           ABC inc
# 25    District 2  Region 3  partner 6          Souce 5           ABC inc
# 26    District 2  Region 3  partner 6          Souce 5           ABC inc
# 27    District 2  Region 3  partner 6          Souce 5           ABC inc
# 28    District 2  Region 3  partner 6          Souce 5           ABC inc
# 29    District 2  Region 3  partner 6          Souce 5           ABC inc
# ..           ...       ...        ...              ...               ...
# 150  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 151  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 152  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 153  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 154  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 155  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 156  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 157  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 158  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 159  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 160  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 161  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 162  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 163  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 164  District 40  Region 4  partner 3          Souce 4           XYZ inc
# 165  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 166  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 167  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 168  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 169  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 170  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 171  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 172  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 173  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 174  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 175  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 176  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 177  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 178  District 41  Region 5  partner 6          Souce 1           XYZ inc
# 179  District 41  Region 5  partner 6          Souce 1           XYZ inc
#
#     target_year target_age  target_quantity
# 0          2017   10-14yrs             1296
# 1          2017   15-29yrs              383
# 2          2017     30+yrs             1571
# 3          2018   10-14yrs              189
# 4          2018   15-29yrs              854
# 5          2018     30+yrs              339
# 6          2019   10-14yrs              840
# 7          2019   15-29yrs              773
# 8          2019     30+yrs              491
# 9          2020   10-14yrs             1906
# 10         2020   15-29yrs             1925
# 11         2020     30+yrs              931
# 12         2021   10-14yrs               61
# 13         2021   15-29yrs              353
# 14         2021     30+yrs             1091
# 15         2017   10-14yrs              722
# 16         2017   15-29yrs              232
# 17         2017     30+yrs             1848
# 18         2018   10-14yrs              972
# 19         2018   15-29yrs               69
# 20         2018     30+yrs             1205
# 21         2019   10-14yrs              422
# 22         2019   15-29yrs              676
# 23         2019     30+yrs              245
# 24         2020   10-14yrs              810
# 25         2020   15-29yrs              664
# 26         2020     30+yrs              452
# 27         2021   10-14yrs              989
# 28         2021   15-29yrs              374
# 29         2021     30+yrs             1790
# ..          ...        ...              ...
# 150        2017   10-14yrs             1627
# 151        2017   15-29yrs              758
# 152        2017     30+yrs              355
# 153        2018   10-14yrs              481
# 154        2018   15-29yrs              745
# 155        2018     30+yrs             1051
# 156        2019   10-14yrs              859
# 157        2019   15-29yrs              419
# 158        2019     30+yrs             1183
# 159        2020   10-14yrs              328
# 160        2020   15-29yrs             1995
# 161        2020     30+yrs              966
# 162        2021   10-14yrs              503
# 163        2021   15-29yrs              976
# 164        2021     30+yrs             1205
# 165        2017   10-14yrs             1470
# 166        2017   15-29yrs             1482
# 167        2017     30+yrs               93
# 168        2018   10-14yrs              766
# 169        2018   15-29yrs             1121
# 170        2018     30+yrs             1231
# 171        2019   10-14yrs             1773
# 172        2019   15-29yrs             1238
# 173        2019     30+yrs              354
# 174        2020   10-14yrs             1976
# 175        2020   15-29yrs              668
# 176        2020     30+yrs              128
# 177        2021   10-14yrs               40
# 178        2021   15-29yrs              649
# 179        2021     30+yrs             1897
#
# [600 rows x 8 columns]

# %% [markdown]
# #### To be honest, It took me a lot of times to understand these codes and concepts. And at this moment I'm not sure that I'm truly understand these or not if I have to do project like this all by myself. So I'mma continue improving myself ! Thank you for you attention :)
